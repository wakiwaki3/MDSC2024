# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import time
import io
import cv2
import textwrap
import matplotlib.patches as patches
import math
import os
from pathlib import Path
from datetime import datetime
import json
import glob

seed = 42
np.random.seed(seed)

# %%
img_dir_path = Path("output", "images")
lbl_dir_path = Path("output", "labels")
jsn_dir_path = Path("output")
today = f'{(int(datetime.now().strftime("%m%d")) - int("1001")):04}'
imgfn_prefix = f"image_{today}_"
jsnfn_prefix = f"label_{today}"
startno = 0
endno = 1e8
wiki_maxnum = 100

datanum = 150
trainnum = int(datanum*0.7)
output_dir_path = Path("dataset_yolo")

# %%
def print_img(img, cvf = False):
    if cvf:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
        # img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    plt.figure(figsize=(10, 10))#figsize=(5,5))
    plt.imshow(img)

# %%
def checkImg(file_path):
    pass

def trans(pts1):
    res = []
    w, h = 640, 480
    for p in pts1:
        newp = [p[0], h-p[1]]
        res.append(newp)
    return np.float32(res)

def get_filenames(img_dir_path):
    res = glob.glob(str(img_dir_path / f"{imgfn_prefix}*.png"))
    return res

def read_json(json_file_path):  
    with open(json_file_path, 'r') as f:  
        data = json.load(f)  
    return data 

def calculate_distance(point1, point2):  
    return math.sqrt((point2[0] - point1[0])**2 + (point2[1] - point1[1])**2) 

def morf(img):
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3, 3))
    res = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel, iterations=2)

    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3, 3))
    res = cv2.morphologyEx(res, cv2.MORPH_OPEN, kernel, iterations=2)
    # kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3, 3))
    # res = cv2.morphologyEx(dst, cv2.MORPH_CLOSE, kernel, iterations=2)
    return res

def preprocessing_image(img):
    gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    denoised_image = cv2.bilateralFilter(gray_image, 9, 75, 75)
    im_edges = cv2.Canny(denoised_image, 20, 10, L2gradient=True)
    mimg = morf(im_edges)
    return mimg

def read_labels(imfn):
    fn = Path(lbl_dir_path, Path(imfn).name[:-4] + ".txt")
    print("fn", fn)
    res = []
    wh = [640, 480, 640, 480]
    with open(fn, 'r') as f:
        for data in f.readlines():
            sd = [int(float(f) * wh[i]) for i, f in enumerate(data[:-2].split(" ")[1:])]
            s = [sd[0] - sd[2]/2, sd[1] + sd[3]/2, sd[0] + sd[2]/2, sd[1] - sd[3]/2]
            s = [int(ss) for ss in s]
            res.append(s)
            
    return res

def add_rect(img, fn):
    labelsdata = read_labels(fn)
    for l in labelsdata:
        ptt1 = (l[0], l[1])
        ptt2 = (l[2], l[3])
        cv2.rectangle(img, ptt1, ptt2, (255, 0, 255))
    return img

def main():
    print(cv2.__version__)
    filenames = get_filenames(img_dir_path)
    width, height = 640, 480
    for i in range(datanum):
        checkFlag = (i >= startno and i < endno)
        if not checkFlag:
            continue

        
        img =  cv2.imread(filenames[i])
        img = cv2.resize(img, (width, height))
        ppimg = preprocessing_image(img)

        # print_img(img, True)
        # print_img(ppimg, True)

        # ppimg = add_rect(ppimg, filenames[i])
        # print_img(ppimg)
        if i < trainnum:
            pt = output_dir_path / "train" / "images" / Path(filenames[i]).name
        else:
            pt = output_dir_path / "val" / "images" / Path(filenames[i]).name
        

        print("pt", pt)
        cv2.imwrite(pt, ppimg)

    # cv2.destroyAllWindows() 

main()
# Out:
# 4.10.0
# pt dataset_yolo\train\images\image_0016_0000000000.png
# pt dataset_yolo\train\images\image_0016_0000000001.png
# pt dataset_yolo\train\images\image_0016_0000000002.png
# pt dataset_yolo\train\images\image_0016_0000000003.png
# pt dataset_yolo\train\images\image_0016_0000000004.png
# pt dataset_yolo\train\images\image_0016_0000000005.png
# pt dataset_yolo\train\images\image_0016_0000000006.png
# pt dataset_yolo\train\images\image_0016_0000000007.png
# pt dataset_yolo\train\images\image_0016_0000000008.png
# pt dataset_yolo\train\images\image_0016_0000000009.png
# pt dataset_yolo\train\images\image_0016_0000000010.png
# pt dataset_yolo\train\images\image_0016_0000000011.png
# pt dataset_yolo\train\images\image_0016_0000000012.png
# pt dataset_yolo\train\images\image_0016_0000000013.png
# pt dataset_yolo\train\images\image_0016_0000000014.png
# pt dataset_yolo\train\images\image_0016_0000000015.png
# pt dataset_yolo\train\images\image_0016_0000000016.png
# pt dataset_yolo\train\images\image_0016_0000000017.png
# pt dataset_yolo\train\images\image_0016_0000000018.png
# pt dataset_yolo\train\images\image_0016_0000000019.png
# pt dataset_yolo\train\images\image_0016_0000000020.png
# pt dataset_yolo\train\images\image_0016_0000000021.png
# pt dataset_yolo\train\images\image_0016_0000000022.png
# pt dataset_yolo\train\images\image_0016_0000000023.png
# pt dataset_yolo\train\images\image_0016_0000000024.png
# pt dataset_yolo\train\images\image_0016_0000000025.png
# pt dataset_yolo\train\images\image_0016_0000000026.png
# pt dataset_yolo\train\images\image_0016_0000000027.png
# pt dataset_yolo\train\images\image_0016_0000000028.png
# pt dataset_yolo\train\images\image_0016_0000000029.png
# pt dataset_yolo\train\images\image_0016_0000000030.png
# pt dataset_yolo\train\images\image_0016_0000000031.png
# pt dataset_yolo\train\images\image_0016_0000000032.png
# pt dataset_yolo\train\images\image_0016_0000000033.png
# pt dataset_yolo\train\images\image_0016_0000000034.png
# pt dataset_yolo\train\images\image_0016_0000000035.png
# pt dataset_yolo\train\images\image_0016_0000000036.png
# pt dataset_yolo\train\images\image_0016_0000000037.png
# pt dataset_yolo\train\images\image_0016_0000000038.png
# pt dataset_yolo\train\images\image_0016_0000000039.png
# pt dataset_yolo\train\images\image_0016_0000000040.png
# pt dataset_yolo\train\images\image_0016_0000000041.png
# pt dataset_yolo\train\images\image_0016_0000000042.png
# pt dataset_yolo\train\images\image_0016_0000000043.png
# pt dataset_yolo\train\images\image_0016_0000000044.png
# pt dataset_yolo\train\images\image_0016_0000000045.png
# pt dataset_yolo\train\images\image_0016_0000000046.png
# pt dataset_yolo\train\images\image_0016_0000000047.png
# pt dataset_yolo\train\images\image_0016_0000000048.png
# pt dataset_yolo\train\images\image_0016_0000000049.png
# pt dataset_yolo\train\images\image_0016_0000000050.png
# pt dataset_yolo\train\images\image_0016_0000000051.png
# pt dataset_yolo\train\images\image_0016_0000000052.png
# pt dataset_yolo\train\images\image_0016_0000000053.png
# pt dataset_yolo\train\images\image_0016_0000000054.png
# pt dataset_yolo\train\images\image_0016_0000000055.png
# pt dataset_yolo\train\images\image_0016_0000000056.png
# pt dataset_yolo\train\images\image_0016_0000000057.png
# pt dataset_yolo\train\images\image_0016_0000000058.png
# pt dataset_yolo\train\images\image_0016_0000000059.png
# pt dataset_yolo\train\images\image_0016_0000000060.png
# pt dataset_yolo\train\images\image_0016_0000000061.png
# pt dataset_yolo\train\images\image_0016_0000000062.png
# pt dataset_yolo\train\images\image_0016_0000000063.png
# pt dataset_yolo\train\images\image_0016_0000000064.png
# pt dataset_yolo\train\images\image_0016_0000000065.png
# pt dataset_yolo\train\images\image_0016_0000000066.png
# pt dataset_yolo\train\images\image_0016_0000000067.png
# pt dataset_yolo\train\images\image_0016_0000000068.png
# pt dataset_yolo\train\images\image_0016_0000000069.png
# pt dataset_yolo\train\images\image_0016_0000000070.png
# pt dataset_yolo\train\images\image_0016_0000000071.png
# pt dataset_yolo\train\images\image_0016_0000000072.png
# pt dataset_yolo\train\images\image_0016_0000000073.png
# pt dataset_yolo\train\images\image_0016_0000000074.png
# pt dataset_yolo\train\images\image_0016_0000000075.png
# pt dataset_yolo\train\images\image_0016_0000000076.png
# pt dataset_yolo\train\images\image_0016_0000000077.png
# pt dataset_yolo\train\images\image_0016_0000000078.png
# pt dataset_yolo\train\images\image_0016_0000000079.png
# pt dataset_yolo\train\images\image_0016_0000000080.png
# pt dataset_yolo\train\images\image_0016_0000000081.png
# pt dataset_yolo\train\images\image_0016_0000000082.png
# pt dataset_yolo\train\images\image_0016_0000000083.png
# pt dataset_yolo\train\images\image_0016_0000000084.png
# pt dataset_yolo\train\images\image_0016_0000000085.png
# pt dataset_yolo\train\images\image_0016_0000000086.png
# pt dataset_yolo\train\images\image_0016_0000000087.png
# pt dataset_yolo\train\images\image_0016_0000000088.png
# pt dataset_yolo\train\images\image_0016_0000000089.png
# pt dataset_yolo\train\images\image_0016_0000000090.png
# pt dataset_yolo\train\images\image_0016_0000000091.png
# pt dataset_yolo\train\images\image_0016_0000000092.png
# pt dataset_yolo\train\images\image_0016_0000000093.png
# pt dataset_yolo\train\images\image_0016_0000000094.png
# pt dataset_yolo\train\images\image_0016_0000000095.png
# pt dataset_yolo\train\images\image_0016_0000000096.png
# pt dataset_yolo\train\images\image_0016_0000000097.png
# pt dataset_yolo\train\images\image_0016_0000000098.png
# pt dataset_yolo\train\images\image_0016_0000000099.png
# pt dataset_yolo\train\images\image_0016_0000000100.png
# pt dataset_yolo\train\images\image_0016_0000000101.png
# pt dataset_yolo\train\images\image_0016_0000000102.png
# pt dataset_yolo\train\images\image_0016_0000000103.png
# pt dataset_yolo\train\images\image_0016_0000000104.png
# pt dataset_yolo\val\images\image_0016_0000000105.png
# pt dataset_yolo\val\images\image_0016_0000000106.png
# pt dataset_yolo\val\images\image_0016_0000000107.png
# pt dataset_yolo\val\images\image_0016_0000000108.png
# pt dataset_yolo\val\images\image_0016_0000000109.png
# pt dataset_yolo\val\images\image_0016_0000000110.png
# pt dataset_yolo\val\images\image_0016_0000000111.png
# pt dataset_yolo\val\images\image_0016_0000000112.png
# pt dataset_yolo\val\images\image_0016_0000000113.png
# pt dataset_yolo\val\images\image_0016_0000000114.png
# pt dataset_yolo\val\images\image_0016_0000000115.png
# pt dataset_yolo\val\images\image_0016_0000000116.png
# pt dataset_yolo\val\images\image_0016_0000000117.png
# pt dataset_yolo\val\images\image_0016_0000000118.png
# pt dataset_yolo\val\images\image_0016_0000000119.png
# pt dataset_yolo\val\images\image_0016_0000000120.png
# pt dataset_yolo\val\images\image_0016_0000000121.png
# pt dataset_yolo\val\images\image_0016_0000000122.png
# pt dataset_yolo\val\images\image_0016_0000000123.png
# pt dataset_yolo\val\images\image_0016_0000000124.png
# pt dataset_yolo\val\images\image_0016_0000000125.png
# pt dataset_yolo\val\images\image_0016_0000000126.png
# pt dataset_yolo\val\images\image_0016_0000000127.png
# pt dataset_yolo\val\images\image_0016_0000000128.png
# pt dataset_yolo\val\images\image_0016_0000000129.png
# pt dataset_yolo\val\images\image_0016_0000000130.png
# pt dataset_yolo\val\images\image_0016_0000000131.png
# pt dataset_yolo\val\images\image_0016_0000000132.png
# pt dataset_yolo\val\images\image_0016_0000000133.png
# pt dataset_yolo\val\images\image_0016_0000000134.png
# pt dataset_yolo\val\images\image_0016_0000000135.png
# pt dataset_yolo\val\images\image_0016_0000000136.png
# pt dataset_yolo\val\images\image_0016_0000000137.png
# pt dataset_yolo\val\images\image_0016_0000000138.png
# pt dataset_yolo\val\images\image_0016_0000000139.png
# pt dataset_yolo\val\images\image_0016_0000000140.png
# pt dataset_yolo\val\images\image_0016_0000000141.png
# pt dataset_yolo\val\images\image_0016_0000000142.png
# pt dataset_yolo\val\images\image_0016_0000000143.png
# pt dataset_yolo\val\images\image_0016_0000000144.png
# pt dataset_yolo\val\images\image_0016_0000000145.png
# pt dataset_yolo\val\images\image_0016_0000000146.png
# pt dataset_yolo\val\images\image_0016_0000000147.png
# pt dataset_yolo\val\images\image_0016_0000000148.png
# pt dataset_yolo\val\images\image_0016_0000000149.png
